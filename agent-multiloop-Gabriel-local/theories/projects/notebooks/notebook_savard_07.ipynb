# %% [markdown]
# # Slot Notebook 07 — Méthode Spectrale Savard
#
# Slot Jupyter pré-provisionné dans l'image Docker. À remplir sans rebuild.

# %%
# from src.spectral.spectral_ratio import compute_spectral_ratio
# compute_spectral_ratio(1, 2)
